# %% [markdown]
# # Matplotlib
# Read the tutorials: "Basic Usage" and "Pyplot Tutorial" in the link: https://matplotlib.org/stable/tutorials/index.html before solving the exercises below. The "Pyplot Tutorial" you do not read in detail but it is good to know about since the fact that there are two approaches to plotting can be confusing if you are not aware of both of the approaches.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Plotting in Matplotlib can be done in either of two ways, which ones? Which way is the recommended approach?

# %% [raw]
# # The stateful (Pyplot) and the object-oriented interfaces, The stateful Pyplot interface is convenient for simple, quick plots and interactive exploration, while the object-oriented approach is recommended for complex, customized plots, allowing precise control.

# %% [markdown]
# ### Explain shortly what a figure, axes, axis and an artist is in Matplotlib.

# %% [raw]
#  # Figure: the whole figure that can be seen as a canvas
#  # Axes: The part of the canvas that the plot is attached to
#  # Axis : the x-axis and y-axis or other scales within an individual subplot
#  # Artist :  artist refers to any individual graphical element within a plot, such as lines, text, shapes, or images. Artists are used to customize and annotate plots.

# %% [markdown]
# ### When plotting in Matplotlib, what is the expected input data type?

# %% [raw]
# # arrays or lists for both x and y data: Line Plots (e.g., plot() function, scatter() function))
# # (strings or integers) for the x-axis and corresponding numerical values for the y-axis. (Bar Plots (e.g., bar() or barh() functions).

# %% [markdown]
# ### Create a plot of the function y = x^2 [from -4 to 4, hint use the np.linspace function] both in the object-oriented approach and the pyplot approach. Your plot should have a title and axis-labels.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Object-Oriented approach
x = np.linspace(-4, 4, 100)
y = x**2
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_title('y = x^2')
ax.set_xlabel('x')
ax.set_ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
# Pyplot approach

plt.plot(x, y)
plt.title("y = x^2")
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Create a figure containing 2  subplots where the first is a scatter plot and the second is a bar plot. You have the data below.

# %%
# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for scatter plot
np.random.seed(15)
random_data_x = np.random.randn(1000)
random_data_y = np.random.randn(1000)
x = np.linspace(-2, 2, 100)
y = x**2

# Data for bar plot
fruit_data = {'grapes': 22, 'apple': 8, 'orange': 15, 'lemon': 20, 'lime': 25}
names = list(fruit_data.keys())
values = list(fruit_data.values())

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4),layout = 'constrained')

# First subplot: Scatter plot
ax1.scatter(random_data_x, random_data_y, alpha=0.5, color='b')
ax1.set_title('Scatter Plot')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')

# Second subplot: Bar plot
ax2.bar(names, values, color='g')
ax2.set_title('Bar Plot')
ax2.set_xlabel('Fruits')
ax2.set_ylabel('Count')

plt.show()
